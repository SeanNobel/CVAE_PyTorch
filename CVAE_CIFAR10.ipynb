# %%
# %matplotlib inline

# import PIL
# PIL.PILLOW_VERSION = PIL.__version__

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import torch.nn.functional as F
from torchvision import datasets, transforms, models

import matplotlib.pyplot as plt

rng = np.random.RandomState(1234)
random_state = 42

device = 'cuda'
batch_size = 256

# %%
transform = transforms.Compose([       
                                # transforms.Resize((32, 32)),
                                # PyTorchはチャネルなど次元の順番が特殊なので整形する
                                # また、0~255の値を0~1に直してくれる
                                transforms.ToTensor(),
                                # transforms.Normalize(mean=(0.5,0.5,0.5), std=(0.5,0.5,0.5)),
                                transforms.Lambda(lambda x: x.view(-1))
])

# データローダーの定義
dataloader_train = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data/cifar10', train=True, download=True, transform=transform),
    batch_size=batch_size,
    shuffle=True
)
dataloader_valid = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data/cifar10', train=False, download=True, transform=transform),
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Prevents NaN by torch.log(0)
def torch_log(x):
  return torch.log(torch.clamp(x, min=1e-10))

# %%
labels_size = 10
in_dim = 32*32*3
hid_size = 512
z_dim = 32

class CVAE(nn.Module):
  def __init__(self, z_dim):
    super(CVAE, self).__init__()
    
    self.dense_enc1 = nn.Linear(in_dim + labels_size, 512)
    self.dense_enc2 = nn.Linear(512, 512)
    self.dense_encmean = nn.Linear(512, z_dim)
    self.dense_encvar = nn.Linear(512, z_dim)

    self.dense_dec1 = nn.Linear(z_dim + labels_size, 512)
    self.dense_dec2 = nn.Linear(512, 512)
    self.dense_dec3 = nn.Linear(512, in_dim)

  def _encoder(self, x, labels):
    in_ = torch.cat([x, labels], dim=1)
    x = F.relu(self.dense_enc1(in_))
    x = F.relu(self.dense_enc2(x))
    mean = self.dense_encmean(x)
    std = F.softplus(self.dense_encvar(x))
    return mean, std

  def _sample_z(self, mean, std):
    # Reparametrization
    epsilon = torch.randn_like(mean).to(device)
    return mean + std * epsilon
  
  def _decoder(self, z, labels):
    in_ = torch.cat([z, labels], dim=1)
    y = F.relu(self.dense_dec1(in_))
    y = F.relu(self.dense_dec2(y))
    y = torch.sigmoid(self.dense_dec3(y))
    return y

  def forward(self, x, labels):
    mean, std = self._encoder(x, labels)
    z = self._sample_z(mean, std)
    x = self._decoder(z, labels)
    return x, z

  def loss(self, x, labels):
    mean, std = self._encoder(x, labels)

    KL = -0.5 * torch.mean(torch.sum(1 + torch_log(std**2) - mean**2 - std**2, dim=1))

    z = self._sample_z(mean, std)
    y = self._decoder(z, labels)

    reconstruction = torch.mean(torch.sum(x * torch_log(y) + (1-x) * torch_log(1-y), dim=1))

    return KL, -reconstruction

# %%
def to_onehot(label):
  return torch.eye(labels_size, device=device, dtype=torch.float32)[label]

# %%
n_epochs = 50
model = CVAE(z_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)


for epoch in range(n_epochs):
  losses_train = []
  model.train()
  for x, labels in dataloader_train:

    labels = to_onehot(labels)
    x = x.to(device)

    KL_loss, reconstruction_loss = model.loss(x, labels)
    loss = KL_loss + reconstruction_loss

    model.zero_grad()
    loss.backward()
    optimizer.step()

    losses_train.append(loss.to('cpu').detach().numpy())

  losses_eval = []
  model.eval()
  for x, labels in dataloader_valid:
    labels = to_onehot(labels)
    x = x.to(device)

    KL_loss, reconstruction_loss = model.loss(x, labels)
    loss = KL_loss + reconstruction_loss

    losses_eval.append(loss.to('cpu').detach().numpy())

  print('EPOCH: %d, Train Lower Bound: %lf, Valid Lower Bound: %lf' %
        (epoch+1, np.average(losses_train), np.average(losses_eval)))
# Out:
# EPOCH: 1, Train Lower Bound: 1992.605591, Valid Lower Bound: 1944.213135
# EPOCH: 2, Train Lower Bound: 1929.771973, Valid Lower Bound: 1923.171875
# EPOCH: 3, Train Lower Bound: 1913.799316, Valid Lower Bound: 1913.208984
# EPOCH: 4, Train Lower Bound: 1900.531250, Valid Lower Bound: 1897.440063
# EPOCH: 5, Train Lower Bound: 1885.423462, Valid Lower Bound: 1884.817017
# EPOCH: 6, Train Lower Bound: 1879.232788, Valid Lower Bound: 1880.930420
# EPOCH: 7, Train Lower Bound: 1874.922974, Valid Lower Bound: 1876.480103
# EPOCH: 8, Train Lower Bound: 1870.475464, Valid Lower Bound: 1873.046143
# EPOCH: 9, Train Lower Bound: 1867.774536, Valid Lower Bound: 1870.654297
# EPOCH: 10, Train Lower Bound: 1866.545288, Valid Lower Bound: 1869.622314
# EPOCH: 11, Train Lower Bound: 1864.573486, Valid Lower Bound: 1867.126343
# EPOCH: 12, Train Lower Bound: 1861.987915, Valid Lower Bound: 1865.631226
# EPOCH: 13, Train Lower Bound: 1861.174438, Valid Lower Bound: 1865.304688
# EPOCH: 14, Train Lower Bound: 1860.246704, Valid Lower Bound: 1869.060181
# EPOCH: 15, Train Lower Bound: 1859.441650, Valid Lower Bound: 1861.832275
# EPOCH: 16, Train Lower Bound: 1856.848511, Valid Lower Bound: 1862.001709
# EPOCH: 17, Train Lower Bound: 1855.589966, Valid Lower Bound: 1858.337524
# EPOCH: 18, Train Lower Bound: 1854.547852, Valid Lower Bound: 1858.717773
# EPOCH: 19, Train Lower Bound: 1853.456177, Valid Lower Bound: 1856.785889
# EPOCH: 20, Train Lower Bound: 1852.237915, Valid Lower Bound: 1857.222290
# EPOCH: 21, Train Lower Bound: 1850.607788, Valid Lower Bound: 1855.273804
# EPOCH: 22, Train Lower Bound: 1849.160889, Valid Lower Bound: 1853.018555
# EPOCH: 23, Train Lower Bound: 1847.354858, Valid Lower Bound: 1849.952393
# EPOCH: 24, Train Lower Bound: 1844.639160, Valid Lower Bound: 1849.006592
# EPOCH: 25, Train Lower Bound: 1843.634277, Valid Lower Bound: 1847.612061
# EPOCH: 26, Train Lower Bound: 1842.609863, Valid Lower Bound: 1845.818604
# EPOCH: 27, Train Lower Bound: 1841.533936, Valid Lower Bound: 1845.157227
# EPOCH: 28, Train Lower Bound: 1840.664673, Valid Lower Bound: 1845.638306
# EPOCH: 29, Train Lower Bound: 1839.728149, Valid Lower Bound: 1850.280884
# EPOCH: 30, Train Lower Bound: 1839.657471, Valid Lower Bound: 1843.777100
# EPOCH: 31, Train Lower Bound: 1838.873535, Valid Lower Bound: 1843.951782
# EPOCH: 32, Train Lower Bound: 1838.090698, Valid Lower Bound: 1843.620728
# EPOCH: 33, Train Lower Bound: 1837.845215, Valid Lower Bound: 1842.694092
# EPOCH: 34, Train Lower Bound: 1837.767578, Valid Lower Bound: 1842.923096
# EPOCH: 35, Train Lower Bound: 1837.249390, Valid Lower Bound: 1841.976807
# EPOCH: 36, Train Lower Bound: 1837.222900, Valid Lower Bound: 1842.064453
# EPOCH: 37, Train Lower Bound: 1836.635864, Valid Lower Bound: 1842.696533
# EPOCH: 38, Train Lower Bound: 1836.429199, Valid Lower Bound: 1842.301025
# EPOCH: 39, Train Lower Bound: 1836.508911, Valid Lower Bound: 1841.795654
# EPOCH: 40, Train Lower Bound: 1835.892700, Valid Lower Bound: 1841.970703
# EPOCH: 41, Train Lower Bound: 1835.729248, Valid Lower Bound: 1841.333984
# EPOCH: 42, Train Lower Bound: 1835.187012, Valid Lower Bound: 1841.110107
# EPOCH: 43, Train Lower Bound: 1834.993652, Valid Lower Bound: 1841.701538
# EPOCH: 44, Train Lower Bound: 1834.716797, Valid Lower Bound: 1840.996826
# EPOCH: 45, Train Lower Bound: 1835.042114, Valid Lower Bound: 1842.925171
# EPOCH: 46, Train Lower Bound: 1834.638428, Valid Lower Bound: 1842.197266
# EPOCH: 47, Train Lower Bound: 1834.101440, Valid Lower Bound: 1839.911133
# EPOCH: 48, Train Lower Bound: 1833.926758, Valid Lower Bound: 1840.000000
# EPOCH: 49, Train Lower Bound: 1833.570435, Valid Lower Bound: 1840.090576
# EPOCH: 50, Train Lower Bound: 1833.486084, Valid Lower Bound: 1840.202759

# %%
fig, axarr = plt.subplots(3, 10, figsize=(20, 5))

model.eval()
for i, ax in enumerate(axarr.flat):
  z = torch.randn(z_dim, device=device).unsqueeze(dim=0)
  label = torch.tensor([9], device=device)
  with torch.no_grad():
    y = model._decoder(z, to_onehot(label))

  y = y.reshape(3, 32, 32).to('cpu').detach().numpy()
  y = np.transpose(y, (1, 2, 0))

  ax.imshow(y)

  ax.axis("off")
